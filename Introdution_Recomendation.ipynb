# %%
import pandas as pd

filmes = pd.read_csv("data/movies.csv")
filmes.columns = ["filmeId", "titulo", "generos"]
filmes = filmes.set_index("filmeId")
filmes.head()
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              generos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy
# 2                         Adventure|Children|Fantasy
# 3                                     Comedy|Romance
# 4                               Comedy|Drama|Romance
# 5                                             Comedy

# %%
notas = pd.read_csv("data/ratings.csv")
notas.columns = ["usuarioId", "filmeId", "nota", "momento"]
notas.head()
# Out:
#    usuarioId  filmeId  nota    momento
# 0          1        1   4.0  964982703
# 1          1        3   4.0  964981247
# 2          1        6   4.0  964982224
# 3          1       47   5.0  964983815
# 4          1       50   5.0  964982931

# %%
notas.describe()
# Out:
#            usuarioId        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09

# %% [markdown]
# # Primeira tentativa de recomendação: heurística de total de votos

# %%
total_de_votos = notas["filmeId"].value_counts()
total_de_votos.head()
# Out:
# filmeId
# 356     329
# 318     317
# 296     307
# 593     279
# 2571    278
# Name: count, dtype: int64

# %%
filmes['total_de_votos'] = total_de_votos
filmes.head()
# Out:
#                                      titulo  \
# filmeId
# 1                          Toy Story (1995)
# 2                            Jumanji (1995)
# 3                   Grumpier Old Men (1995)
# 4                  Waiting to Exhale (1995)
# 5        Father of the Bride Part II (1995)
#
#                                              generos  total_de_votos
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 2                         Adventure|Children|Fantasy           110.0
# 3                                     Comedy|Romance            52.0
# 4                               Comedy|Drama|Romance             7.0
# 5                                             Comedy            49.0

# %%
filmes.sort_values("total_de_votos", ascending = False).head(10)
# Out:
#                                             titulo  \
# filmeId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                   generos  total_de_votos
# filmeId
# 356              Comedy|Drama|Romance|War           329.0
# 318                           Crime|Drama           317.0
# 296           Comedy|Crime|Drama|Thriller           307.0
# 593                 Crime|Horror|Thriller           279.0
# 2571               Action|Sci-Fi|Thriller           278.0
# 260               Action|Adventure|Sci-Fi           251.0
# 480      Action|Adventure|Sci-Fi|Thriller           238.0
# 110                      Action|Drama|War           237.0
# 589                         Action|Sci-Fi           224.0
# 527                             Drama|War           220.0

# %%
notas_medias = notas.groupby("filmeId").mean()["nota"]
notas_medias.head()
# Out:
# filmeId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: nota, dtype: float64

# %%
filmes["nota_media"] = notas_medias
filmes.sort_values("total_de_votos", ascending = False).head(10)
# Out:
#                                             titulo  \
# filmeId
# 356                            Forrest Gump (1994)
# 318               Shawshank Redemption, The (1994)
# 296                            Pulp Fiction (1994)
# 593               Silence of the Lambs, The (1991)
# 2571                            Matrix, The (1999)
# 260      Star Wars: Episode IV - A New Hope (1977)
# 480                           Jurassic Park (1993)
# 110                              Braveheart (1995)
# 589              Terminator 2: Judgment Day (1991)
# 527                        Schindler's List (1993)
#
#                                   generos  total_de_votos  nota_media
# filmeId
# 356              Comedy|Drama|Romance|War           329.0    4.164134
# 318                           Crime|Drama           317.0    4.429022
# 296           Comedy|Crime|Drama|Thriller           307.0    4.197068
# 593                 Crime|Horror|Thriller           279.0    4.161290
# 2571               Action|Sci-Fi|Thriller           278.0    4.192446
# 260               Action|Adventure|Sci-Fi           251.0    4.231076
# 480      Action|Adventure|Sci-Fi|Thriller           238.0    3.750000
# 110                      Action|Drama|War           237.0    4.031646
# 589                         Action|Sci-Fi           224.0    3.970982
# 527                             Drama|War           220.0    4.225000

# %% [markdown]
# # Uma segunda heurística: nota média e filtrando votos

# %%
filmes.sort_values("nota_media", ascending = False).head(10)
# Out:
#                                                     titulo  \
# filmeId
# 99                    Heidi Fleiss: Hollywood Madam (1995)
# 64501                                 Che: Part Two (2008)
# 1349     Vampire in Venice (Nosferatu a Venezia) (Nosfe...
# 86721                             Idiots and Angels (2008)
# 86668                 Louis Theroux: Law & Disorder (2008)
# 7815                                   True Stories (1986)
# 2972                   Red Sorghum (Hong gao liang) (1987)
# 2969     Man and a Woman, A (Un homme et une femme) (1966)
# 163925                        Wings, Legs and Tails (1986)
# 87834            My Life as McDull (Mak dau goo si) (2001)
#
#                          generos  total_de_votos  nota_media
# filmeId
# 99                   Documentary             2.0         5.0
# 64501                  Drama|War             1.0         5.0
# 1349                      Horror             1.0         5.0
# 86721    Animation|Drama|Fantasy             1.0         5.0
# 86668                Documentary             1.0         5.0
# 7815              Comedy|Musical             1.0         5.0
# 2972                   Drama|War             1.0         5.0
# 2969               Drama|Romance             1.0         5.0
# 163925          Animation|Comedy             1.0         5.0
# 87834     Animation|Comedy|Drama             1.0         5.0

# %%
filmes.query("total_de_votos >= 10").sort_values("nota_media", ascending = False).head(10)
# Out:
#                                                 titulo  \
# filmeId
# 1041                             Secrets & Lies (1996)
# 3451               Guess Who's Coming to Dinner (1967)
# 1178                             Paths of Glory (1957)
# 1104                  Streetcar Named Desire, A (1951)
# 2360                  Celebration, The (Festen) (1998)
# 1217                                        Ran (1985)
# 318                   Shawshank Redemption, The (1994)
# 951                             His Girl Friday (1940)
# 1927             All Quiet on the Western Front (1930)
# 922      Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)
#
#                          generos  total_de_votos  nota_media
# filmeId
# 1041                       Drama            11.0    4.590909
# 3451                       Drama            11.0    4.545455
# 1178                   Drama|War            12.0    4.541667
# 1104                       Drama            20.0    4.475000
# 2360                       Drama            12.0    4.458333
# 1217                   Drama|War            15.0    4.433333
# 318                  Crime|Drama           317.0    4.429022
# 951               Comedy|Romance            14.0    4.392857
# 1927            Action|Drama|War            10.0    4.350000
# 922      Drama|Film-Noir|Romance            27.0    4.333333

# %%
filmes_com_mais_de_50_votos = filmes.query("total_de_votos >= 50")
filmes_com_mais_de_50_votos.sort_values("nota_media", ascending = False).head(10)
# Out:
#                                                     titulo  \
# filmeId
# 318                       Shawshank Redemption, The (1994)
# 858                                  Godfather, The (1972)
# 2959                                     Fight Club (1999)
# 1276                                 Cool Hand Luke (1967)
# 750      Dr. Strangelove or: How I Learned to Stop Worr...
# 904                                     Rear Window (1954)
# 1221                        Godfather: Part II, The (1974)
# 48516                                 Departed, The (2006)
# 1213                                     Goodfellas (1990)
# 912                                      Casablanca (1942)
#
#                              generos  total_de_votos  nota_media
# filmeId
# 318                      Crime|Drama           317.0    4.429022
# 858                      Crime|Drama           192.0    4.289062
# 2959     Action|Crime|Drama|Thriller           218.0    4.272936
# 1276                           Drama            57.0    4.271930
# 750                       Comedy|War            97.0    4.268041
# 904                 Mystery|Thriller            84.0    4.261905
# 1221                     Crime|Drama           129.0    4.259690
# 48516           Crime|Drama|Thriller           107.0    4.252336
# 1213                     Crime|Drama           126.0    4.250000
# 912                    Drama|Romance           100.0    4.240000

# %%
eu_assisti = [1, 21, 19, 10, 11, 7, 2]
filmes.loc[eu_assisti]
# Out:
#                                         titulo  \
# filmeId
# 1                             Toy Story (1995)
# 21                           Get Shorty (1995)
# 19       Ace Ventura: When Nature Calls (1995)
# 10                            GoldenEye (1995)
# 11              American President, The (1995)
# 7                               Sabrina (1995)
# 2                               Jumanji (1995)
#
#                                              generos  total_de_votos  \
# filmeId
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 21                             Comedy|Crime|Thriller            89.0
# 19                                            Comedy            88.0
# 10                         Action|Adventure|Thriller           132.0
# 11                              Comedy|Drama|Romance            70.0
# 7                                     Comedy|Romance            54.0
# 2                         Adventure|Children|Fantasy           110.0
#
#          nota_media
# filmeId
# 1          3.920930
# 21         3.494382
# 19         2.727273
# 10         3.496212
# 11         3.671429
# 7          3.185185
# 2          3.431818

# %%
aventura_infantil_e_fantasia = filmes_com_mais_de_50_votos.query("generos=='Adventure|Children|Fantasy'")
aventura_infantil_e_fantasia.drop(eu_assisti, errors='ignore').sort_values("nota_media", ascending = False).head(10)
# Out:
#                                                     titulo  \
# filmeId
# 4896     Harry Potter and the Sorcerer's Stone (a.k.a. ...
# 41566    Chronicles of Narnia: The Lion, the Witch and ...
#
#                             generos  total_de_votos  nota_media
# filmeId
# 4896     Adventure|Children|Fantasy           107.0    3.761682
# 41566    Adventure|Children|Fantasy            62.0    3.443548

# %%
# Collaborative filtering x Content based filtering

# %% [markdown]
# # Procurar usuários "similares"

# %% [markdown]
# - joão deu nota 4 no filme toy story
# - maria deu nota 5 no filme toy story
# - paulo deu nota 3 no filme toy story
# - joana deu nota 3.5 no filme toy story
#
# x-y ==> distância

# %%
import matplotlib.pyplot as plt
plt.plot(4, 4.5, "go")
plt.plot(5, 5, "yo")
plt.legend(["João", "Maria"])
plt.title("Calcular a distância entre dois usuários")

plt.plot([4, 5], [4.5, 4.5], color="b", linestyle="-")
plt.plot([4, 5], [4.5, 5], color="b", linestyle="-")
plt.plot([5, 5], [4.5, 5], color="b", linestyle="-")

# %%
import numpy as np

joao = np.array([4, 4.5])
maria = np.array([5, 5])

joao - maria
# Out:
# array([-1. , -0.5])

# %%
from math import sqrt

def pitagoras(a,b):
  (delta_x, delta_y) = a - b
  return sqrt(delta_x * delta_x + delta_y * delta_y)

pitagoras(joao, maria)
# Out:
# 1.118033988749895

# %%
def pitagoras(a,b):
  return np.linalg.norm(a - b)

pitagoras(joao, maria)
# Out:
# np.float64(1.118033988749895)

# %%
import matplotlib.pyplot as plt
plt.plot(4, 4.5, "go")
plt.plot(5, 5, "yo")
plt.plot(3.5, 4.5, "bo")
plt.legend(["João", "Maria", "Joaquina"])
plt.title("Calcular a distância entre usuários")
# Out:
# Text(0.5, 1.0, 'Calcular a distância entre usuários')

# %%
joaquina = np.array([3.5, 4.5])

print(pitagoras(joao, maria))
print(pitagoras(joao, joaquina))
# Out:
# 1.118033988749895
# 0.5

# %% [markdown]
# # Distância entre usuários do dataset

# %%
def distancia_de_vetores(a,b):
  return np.linalg.norm(a - b)

# %%
def notas_do_usuario(usuario):
  notas_do_usuario = notas.query("usuarioId==%d" % usuario)
  notas_do_usuario = notas_do_usuario[["filmeId", "nota"]].set_index("filmeId")
  return notas_do_usuario

# %%
usuario1 = notas_do_usuario(1)
usuario4 = notas_do_usuario(4)

# %%
usuario1.head()
# Out:
#          nota
# filmeId
# 1         4.0
# 3         4.0
# 6         4.0
# 47        5.0
# 50        5.0

# %%
usuario4.head()
# Out:
#          nota
# filmeId
# 21        3.0
# 32        2.0
# 45        3.0
# 47        2.0
# 52        3.0

# %%
diferencas = usuario1.join(usuario4, lsuffix="_esquerda", rsuffix="_direita").dropna()
distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
# Out:
# np.float64(11.135528725660043)

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2):
  notas1 = notas_do_usuario(usuario_id1)
  notas2 = notas_do_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()
  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
distancia_de_usuarios(1,4)
# Out:
# [1, 4, np.float64(11.135528725660043)]

# %%
quantidade_de_usuarios = len(notas['usuarioId'].unique())
print("Temos %d usuarios" % quantidade_de_usuarios)
# Out:
# Temos 610 usuarios

# %%
def distancia_de_todos(voce_id):
  distancias = []
  for usuario_id in notas['usuarioId'].unique():
    informacoes = distancia_de_usuarios(voce_id, usuario_id)
    distancias.append(informacoes)
  return distancias

distancia_de_todos(1)[:5]
# Out:
# [[1, np.int64(1), np.float64(0.0)],
#  [1, np.int64(2), np.float64(1.4142135623730951)],
#  [1, np.int64(3), np.float64(8.200609733428363)],
#  [1, np.int64(4), np.float64(11.135528725660043)],
#  [1, np.int64(5), np.float64(3.7416573867739413)]]

# %%
def distancia_de_todos(voce_id):
  todos_os_usuarios = notas['usuarioId'].unique()
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

distancia_de_todos(1).head()
# Out:
#    voce  outra_pessoa  distancia
# 0     1             1   0.000000
# 1     1             2   1.414214
# 2     1             3   8.200610
# 3     1             4  11.135529
# 4     1             5   3.741657

# %%
notas_do_usuario(1).join(notas_do_usuario(5), lsuffix="_1", rsuffix="5").dropna()
# Out:
#          nota_1  nota5
# filmeId
# 1           4.0    4.0
# 50          5.0    4.0
# 110         4.0    4.0
# 296         3.0    5.0
# 316         3.0    2.0
# 349         4.0    3.0
# 367         4.0    4.0
# 457         5.0    4.0
# 527         5.0    5.0
# 590         4.0    5.0
# 592         4.0    3.0
# 596         5.0    5.0
# 608         5.0    3.0

# %%
notas_do_usuario(1).join(notas_do_usuario(2), lsuffix="_1", rsuffix="2").dropna()
# Out:
#          nota_1  nota2
# filmeId
# 333         5.0    4.0
# 3578        5.0    4.0

# %%
notas_do_usuario(1).join(notas_do_usuario(3), lsuffix="_1", rsuffix="3").dropna()
# Out:
#          nota_1  nota3
# filmeId
# 527         5.0    0.5
# 1275        5.0    3.5
# 1587        5.0    4.5
# 2018        5.0    0.5
# 2090        5.0    0.5
# 2105        4.0    2.0
# 3703        5.0    5.0

# %% [markdown]
# # Usuários sem filmes em comum são colocados bem distante um do outro

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2, minimo = 5):
  notas1 = notas_do_usuario(usuario_id1)
  notas2 = notas_do_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()
  
  if(len(diferencas) < minimo):
    return [usuario_id1, usuario_id2, 100000]
  
  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
distancia_de_todos(1).head()
# Out:
#    voce  outra_pessoa      distancia
# 0     1             1       0.000000
# 1     1             2  100000.000000
# 2     1             3       8.200610
# 3     1             4      11.135529
# 4     1             5       3.741657

# %%
def mais_proximos_de(voce_id):
  distancias = distancia_de_todos(voce_id)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias

# %%
mais_proximos_de(1).head()
# Out:
#               voce  distancia
# outra_pessoa
# 77               1   0.000000
# 511              1   0.500000
# 366              1   0.707107
# 258              1   1.000000
# 9                1   1.000000

# %% [markdown]
# # Parâmetros para teste

# %%
def mais_proximos_de(voce_id, n = None):
  distancias = distancia_de_todos(voce_id, n = n)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias

# %%
def distancia_de_todos(voce_id, n = None):
  todos_os_usuarios = notas['usuarioId'].unique()
  if n:
    todos_os_usuarios = todos_os_usuarios[:n]
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

# %%
mais_proximos_de(1, n = 50)
# Out:
#               voce      distancia
# outra_pessoa
# 9                1       1.000000
# 49               1       1.000000
# 13               1       1.414214
# 25               1       1.414214
# 30               1       1.802776
# 35               1       2.236068
# 26               1       2.236068
# 46               1       3.316625
# 44               1       3.741657
# 8                1       3.741657
# 5                1       3.741657
# 37               1       4.000000
# 48               1       4.123106
# 11               1       4.242641
# 24               1       4.415880
# 29               1       4.555217
# 31               1       4.582576
# 17               1       4.609772
# 43               1       4.795832
# 14               1       5.000000
# 32               1       5.196152
# 22               1       5.244044
# 23               1       5.408327
# 38               1       5.567764
# 15               1       5.852350
# 33               1       5.916080
# 47               1       6.244998
# 34               1       6.363961
# 20               1       6.480741
# 36               1       6.519202
# 40               1       6.855655
# 7                1       7.106335
# 16               1       7.228416
# 50               1       7.331439
# 10               1       7.858117
# 3                1       8.200610
# 18               1       8.426150
# 6                1       8.602325
# 21               1       9.096703
# 27               1       9.219544
# 41               1      10.198039
# 45               1      10.653638
# 39               1      11.090537
# 4                1      11.135529
# 42               1      12.000000
# 28               1      14.882876
# 19               1      17.606817
# 2                1  100000.000000
# 12               1  100000.000000

# %%
def distancia_de_usuarios(usuario_id1, usuario_id2, minimo = 5):
  notas1 = notas_do_usuario(usuario_id1)
  notas2 = notas_do_usuario(usuario_id2)
  diferencas = notas1.join(notas2, lsuffix="_esquerda", rsuffix="_direita").dropna()
  
  if(len(diferencas) < minimo):
    return None
  
  distancia =  distancia_de_vetores(diferencas['nota_esquerda'], diferencas['nota_direita'])
  return [usuario_id1, usuario_id2, distancia]

# %%
def distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = None):
  todos_os_usuarios = notas['usuarioId'].unique()
  if numero_de_usuarios_a_analisar:
    todos_os_usuarios = todos_os_usuarios[:numero_de_usuarios_a_analisar]
  distancias = [distancia_de_usuarios(voce_id, usuario_id) for usuario_id in todos_os_usuarios]
  distancias = list(filter(None, distancias))
  distancias = pd.DataFrame(distancias, columns = ["voce", "outra_pessoa", "distancia"])
  return distancias

# %%
def mais_proximos_de(voce_id, numero_de_usuarios_a_analisar = None):
  distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias

# %%
mais_proximos_de(1, numero_de_usuarios_a_analisar = 50)
# Out:
#               voce  distancia
# outra_pessoa
# 9                1   1.000000
# 49               1   1.000000
# 13               1   1.414214
# 25               1   1.414214
# 30               1   1.802776
# 35               1   2.236068
# 26               1   2.236068
# 46               1   3.316625
# 44               1   3.741657
# 5                1   3.741657
# 8                1   3.741657
# 37               1   4.000000
# 48               1   4.123106
# 11               1   4.242641
# 24               1   4.415880
# 29               1   4.555217
# 31               1   4.582576
# 17               1   4.609772
# 43               1   4.795832
# 14               1   5.000000
# 32               1   5.196152
# 22               1   5.244044
# 23               1   5.408327
# 38               1   5.567764
# 15               1   5.852350
# 33               1   5.916080
# 47               1   6.244998
# 34               1   6.363961
# 20               1   6.480741
# 36               1   6.519202
# 40               1   6.855655
# 7                1   7.106335
# 16               1   7.228416
# 50               1   7.331439
# 10               1   7.858117
# 3                1   8.200610
# 18               1   8.426150
# 6                1   8.602325
# 21               1   9.096703
# 27               1   9.219544
# 41               1  10.198039
# 45               1  10.653638
# 39               1  11.090537
# 4                1  11.135529
# 42               1  12.000000
# 28               1  14.882876
# 19               1  17.606817

# %%
def sugere_para(voce, numero_de_usuarios_a_analisar = None):
  notas_de_voce = notas_do_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = mais_proximos_de(voce, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  similar = similares.iloc[0].name
  notas_do_similar = notas_do_usuario(similar)
  notas_do_similar = notas_do_similar.drop(filmes_que_voce_ja_viu, errors='ignore')
  recomendacoes = notas_do_similar.sort_values("nota", ascending=False)
  return recomendacoes.join(filmes)

# %%
sugere_para(1, numero_de_usuarios_a_analisar=50).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 2300      5.0                              Producers, The (1968)
# 5481      5.0                 Austin Powers in Goldmember (2002)
# 5902      5.0                                  Adaptation (2002)
# 4993      5.0  Lord of the Rings: The Fellowship of the Ring,...
# 5952      5.0      Lord of the Rings: The Two Towers, The (2002)
#
#                       generos  total_de_votos  nota_media
# filmeId
# 2300                   Comedy            33.0    3.969697
# 5481                   Comedy            65.0    2.846154
# 5902     Comedy|Drama|Romance            46.0    3.945652
# 4993        Adventure|Fantasy           198.0    4.106061
# 5952        Adventure|Fantasy           188.0    4.021277

# %%
sugere_para(1).head()
# Out:
#          nota                                             titulo  \
# filmeId
# 3996      5.0  Crouching Tiger, Hidden Dragon (Wo hu cang lon...
# 4993      5.0  Lord of the Rings: The Fellowship of the Ring,...
# 5349      5.0                                  Spider-Man (2002)
# 7153      5.0  Lord of the Rings: The Return of the King, The...
# 5952      5.0      Lord of the Rings: The Two Towers, The (2002)
#
#                                   generos  total_de_votos  nota_media
# filmeId
# 3996                 Action|Drama|Romance           110.0    3.836364
# 4993                    Adventure|Fantasy           198.0    4.106061
# 5349     Action|Adventure|Sci-Fi|Thriller           122.0    3.540984
# 7153       Action|Adventure|Drama|Fantasy           185.0    4.118919
# 5952                    Adventure|Fantasy           188.0    4.021277

# %% [markdown]
# # Sugerindo baseado em vários usuários

# %%
def mais_proximos_de(voce_id, n_mais_proximos=10, numero_de_usuarios_a_analisar = None):
  distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias.head(n_mais_proximos)

# %%
mais_proximos_de(1, n_mais_proximos = 2, numero_de_usuarios_a_analisar=300)
# Out:
#               voce  distancia
# outra_pessoa
# 77               1        0.0
# 49               1        1.0

# %%
def sugere_para(voce, n_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
  notas_de_voce = notas_do_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = mais_proximos_de(voce, n_mais_proximos = n_mais_proximos, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  usuarios_similares = similares.index
  notas_dos_similares = notas.set_index("usuarioId").loc[usuarios_similares]
  recomendacoes = notas_dos_similares.groupby("filmeId").mean()[["nota"]]
  recomendacoes = recomendacoes.sort_values("nota", ascending=False)
  return recomendacoes.join(filmes)

# %%
sugere_para(1, numero_de_usuarios_a_analisar = 50).head()
# Out:
#          nota                              titulo                     generos  \
# filmeId
# 58        5.0   Postman, The (Postino, Il) (1994)        Comedy|Drama|Romance
# 62        5.0           Mr. Holland's Opus (1995)                       Drama
# 60        5.0  Indian in the Cupboard, The (1995)  Adventure|Children|Fantasy
# 247       5.0           Heavenly Creatures (1994)                 Crime|Drama
# 173       5.0                  Judge Dredd (1995)         Action|Crime|Sci-Fi
#
#          total_de_votos  nota_media
# filmeId
# 58                 37.0    4.027027
# 62                 80.0    3.706250
# 60                 34.0    3.235294
# 247                21.0    3.928571
# 173                62.0    2.669355

# %%
sugere_para(1, numero_de_usuarios_a_analisar = 300).head()
# Out:
#          nota                                            titulo  \
# filmeId
# 187593    5.0                                 Deadpool 2 (2018)
# 180095    5.0                                     Wonder (2017)
# 177593    5.0  Three Billboards Outside Ebbing, Missouri (2017)
# 55247     5.0                              Into the Wild (2007)
# 60069     5.0                                     WALL·E (2008)
#
#                                              generos  total_de_votos  \
# filmeId
# 187593                          Action|Comedy|Sci-Fi            12.0
# 180095                                         Drama             3.0
# 177593                                   Crime|Drama             8.0
# 55247                         Action|Adventure|Drama            41.0
# 60069    Adventure|Animation|Children|Romance|Sci-Fi           104.0
#
#          nota_media
# filmeId
# 187593     3.875000
# 180095     4.000000
# 177593     4.750000
# 55247      3.902439
# 60069      4.057692

# %%
sugere_para(1).head()
# Out:
#          nota                                     titulo  \
# filmeId
# 150548    5.0      Sherlock: The Abominable Bride (2016)
# 32        5.0  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)
# 260       5.0  Star Wars: Episode IV - A New Hope (1977)
# 2300      5.0                      Producers, The (1968)
# 2161      5.0              NeverEnding Story, The (1984)
#
#                                      generos  total_de_votos  nota_media
# filmeId
# 150548   Action|Crime|Drama|Mystery|Thriller            10.0    3.850000
# 32                   Mystery|Sci-Fi|Thriller           177.0    3.983051
# 260                  Action|Adventure|Sci-Fi           251.0    4.231076
# 2300                                  Comedy            33.0    3.969697
# 2161              Adventure|Children|Fantasy            43.0    3.581395

# %%
def knn(voce_id, k_mais_proximos=10, numero_de_usuarios_a_analisar = None):
  distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id)
  return distancias.head(k_mais_proximos)

# %%
def sugere_para(voce, k_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
  notas_de_voce = notas_do_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = knn(voce, k_mais_proximos = k_mais_proximos, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  usuarios_similares = similares.index
  notas_dos_similares = notas.set_index("usuarioId").loc[usuarios_similares]
  recomendacoes = notas_dos_similares.groupby("filmeId").mean()[["nota"]]
  recomendacoes = recomendacoes.sort_values("nota", ascending=False)
  return recomendacoes.join(filmes)

# %% [markdown]
# # Testar um usuário novo

# %%
filmes.loc[[122904, 1246, 2529, 2329 , 2324 , 1 , 7 , 2 ,1196, 260]]
# Out:
#                                                     titulo  \
# filmeId
# 122904                                     Deadpool (2016)
# 1246                             Dead Poets Society (1989)
# 2529                             Planet of the Apes (1968)
# 2329                             American History X (1998)
# 2324            Life Is Beautiful (La Vita è bella) (1997)
# 1                                         Toy Story (1995)
# 7                                           Sabrina (1995)
# 2                                           Jumanji (1995)
# 1196     Star Wars: Episode V - The Empire Strikes Back...
# 260              Star Wars: Episode IV - A New Hope (1977)
#
#                                              generos  total_de_votos  \
# filmeId
# 122904                Action|Adventure|Comedy|Sci-Fi            54.0
# 1246                                           Drama            86.0
# 2529                             Action|Drama|Sci-Fi            56.0
# 2329                                     Crime|Drama           129.0
# 2324                        Comedy|Drama|Romance|War            88.0
# 1        Adventure|Animation|Children|Comedy|Fantasy           215.0
# 7                                     Comedy|Romance            54.0
# 2                         Adventure|Children|Fantasy           110.0
# 1196                         Action|Adventure|Sci-Fi           211.0
# 260                          Action|Adventure|Sci-Fi           251.0
#
#          nota_media
# filmeId
# 122904     3.833333
# 1246       3.959302
# 2529       3.803571
# 2329       4.217054
# 2324       4.147727
# 1          3.920930
# 7          3.185185
# 2          3.431818
# 1196       4.215640
# 260        4.231076

# %%
def novo_usuario(dados):
  novo_usuario = notas['usuarioId'].max()+1
  notas_do_usuario_novo = pd.DataFrame(dados, columns=["filmeId", "nota"])
  notas_do_usuario_novo['usuarioId'] = novo_usuario
  return pd.concat([notas, notas_do_usuario_novo])

# %%
notas = novo_usuario([[122904,2],[1246,5],[2529,2],[2329,5],[2324,5],[1,2],[7,0.5],[2,2],[1196,1],[260,1]])
notas.tail()
# Out:
#    usuarioId  filmeId  nota  momento
# 5        611        1   2.0      NaN
# 6        611        7   0.5      NaN
# 7        611        2   2.0      NaN
# 8        611     1196   1.0      NaN
# 9        611      260   1.0      NaN

# %%
sugere_para(611).head()
# Out:
#          nota                                     titulo              generos  \
# filmeId
# 971       5.0               Cat on a Hot Tin Roof (1958)                Drama
# 7121      5.0                          Adam's Rib (1949)       Comedy|Romance
# 1411      5.0                              Hamlet (1996)  Crime|Drama|Romance
# 6807      5.0  Monty Python's The Meaning of Life (1983)               Comedy
# 51931     5.0                       Reign Over Me (2007)                Drama
#
#          total_de_votos  nota_media
# filmeId
# 971                10.0        4.10
# 7121                4.0        4.75
# 1411               16.0        4.00
# 6807               40.0        3.95
# 51931               5.0        4.10

# %% [markdown]
# # Utilizar somente as notas de filmes com mais de 50 votos

# %%
notas = notas.set_index("filmeId").loc[filmes_com_mais_de_50_votos.index]
notas.head()
# Out:
#          usuarioId  nota       momento
# filmeId
# 1                1   4.0  9.649827e+08
# 1                5   4.0  8.474350e+08
# 1                7   4.5  1.106636e+09
# 1               15   2.5  1.510578e+09
# 1               17   4.5  1.305696e+09

# %%
notas = notas.reset_index()
notas.head()
# Out:
#    filmeId  usuarioId  nota       momento
# 0        1          1   4.0  9.649827e+08
# 1        1          5   4.0  8.474350e+08
# 2        1          7   4.5  1.106636e+09
# 3        1         15   2.5  1.510578e+09
# 4        1         17   4.5  1.305696e+09

# %%
sugere_para(611).head()
# Out:
#              nota                          titulo                  generos  \
# filmeId
# 112852   5.000000  Guardians of the Galaxy (2014)  Action|Adventure|Sci-Fi
# 74458    4.750000           Shutter Island (2010)   Drama|Mystery|Thriller
# 71535    4.666667               Zombieland (2009)     Action|Comedy|Horror
# 1090     4.500000                  Platoon (1986)                Drama|War
# 300      4.500000                Quiz Show (1994)                    Drama
#
#          total_de_votos  nota_media
# filmeId
# 112852             59.0    4.050847
# 74458              67.0    4.022388
# 71535              53.0    3.877358
# 1090               63.0    3.984127
# 300                81.0    3.518519

# %%
def sugere_para(voce, k_mais_proximos = 10, numero_de_usuarios_a_analisar = None):
  notas_de_voce = notas_do_usuario(voce)
  filmes_que_voce_ja_viu = notas_de_voce.index

  similares = knn(voce, k_mais_proximos = k_mais_proximos, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  usuarios_similares = similares.index
  notas_dos_similares = notas.set_index("usuarioId").loc[usuarios_similares]
  recomendacoes = notas_dos_similares.groupby("filmeId").mean()[["nota"]]
  aparicoes = notas_dos_similares.groupby("filmeId").count()[['nota']]
  
  filtro_minimo = k_mais_proximos / 2
  recomendacoes = recomendacoes.join(aparicoes, lsuffix="_media_dos_usuarios", rsuffix="_aparicoes_nos_usuarios")
  recomendacoes = recomendacoes.query("nota_aparicoes_nos_usuarios >= %.2f" % filtro_minimo)  
  recomendacoes = recomendacoes.sort_values("nota_media_dos_usuarios", ascending=False)
  
  recomendacoes = recomendacoes.drop(filmes_que_voce_ja_viu,errors='ignore')
  return recomendacoes.join(filmes)

# %%
def knn(voce_id, k_mais_proximos=10, numero_de_usuarios_a_analisar = None):
  distancias = distancia_de_todos(voce_id, numero_de_usuarios_a_analisar = numero_de_usuarios_a_analisar)
  distancias = distancias.sort_values("distancia")
  distancias = distancias.set_index("outra_pessoa").drop(voce_id, errors='ignore')
  return distancias.head(k_mais_proximos)

# %%
sugere_para(1, numero_de_usuarios_a_analisar=500)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 318                     4.583333                            6
#
#                                    titulo      generos  total_de_votos  \
# filmeId
# 318      Shawshank Redemption, The (1994)  Crime|Drama           317.0
#
#          nota_media
# filmeId
# 318        4.429022

# %%
sugere_para(611).head(10)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 318                     4.500000                            8
# 919                     4.400000                            5
# 79132                   4.357143                            7
# 356                     4.350000                           10
# 7361                    4.312500                            8
# 904                     4.300000                            5
# 593                     4.222222                            9
# 46578                   4.214286                            7
# 4246                    4.200000                            5
# 4011                    4.200000                            5
#
#                                                titulo  \
# filmeId
# 318                  Shawshank Redemption, The (1994)
# 919                          Wizard of Oz, The (1939)
# 79132                                Inception (2010)
# 356                               Forrest Gump (1994)
# 7361     Eternal Sunshine of the Spotless Mind (2004)
# 904                                Rear Window (1954)
# 593                  Silence of the Lambs, The (1991)
# 46578                     Little Miss Sunshine (2006)
# 4246                     Bridget Jones's Diary (2001)
# 4011                                    Snatch (2000)
#
#                                                  generos  total_de_votos  \
# filmeId
# 318                                          Crime|Drama           317.0
# 919                   Adventure|Children|Fantasy|Musical            92.0
# 79132    Action|Crime|Drama|Mystery|Sci-Fi|Thriller|IMAX           143.0
# 356                             Comedy|Drama|Romance|War           329.0
# 7361                                Drama|Romance|Sci-Fi           131.0
# 904                                     Mystery|Thriller            84.0
# 593                                Crime|Horror|Thriller           279.0
# 46578                             Adventure|Comedy|Drama            77.0
# 4246                                Comedy|Drama|Romance            65.0
# 4011                               Comedy|Crime|Thriller            93.0
#
#          nota_media
# filmeId
# 318        4.429022
# 919        3.880435
# 79132      4.066434
# 356        4.164134
# 7361       4.160305
# 904        4.261905
# 593        4.161290
# 46578      3.883117
# 4246       3.623077
# 4011       4.155914

# %%
sugere_para(611, k_mais_proximos=20).head(10)
# Out:
#          nota_media_dos_usuarios  nota_aparicoes_nos_usuarios  \
# filmeId
# 593                     4.266667                           15
# 296                     4.264706                           17
# 4973                    4.192308                           13
# 318                     4.176471                           17
# 46578                   4.150000                           10
# 590                     4.136364                           11
# 7361                    4.133333                           15
# 4878                    4.125000                           12
# 5618                    4.100000                           10
# 1213                    4.100000                           10
#
#                                                     titulo  \
# filmeId
# 593                       Silence of the Lambs, The (1991)
# 296                                    Pulp Fiction (1994)
# 4973     Amelie (Fabuleux destin d'Amélie Poulain, Le) ...
# 318                       Shawshank Redemption, The (1994)
# 46578                          Little Miss Sunshine (2006)
# 590                              Dances with Wolves (1990)
# 7361          Eternal Sunshine of the Spotless Mind (2004)
# 4878                                   Donnie Darko (2001)
# 5618     Spirited Away (Sen to Chihiro no kamikakushi) ...
# 1213                                     Goodfellas (1990)
#
#                                generos  total_de_votos  nota_media
# filmeId
# 593              Crime|Horror|Thriller           279.0    4.161290
# 296        Comedy|Crime|Drama|Thriller           307.0    4.197068
# 4973                    Comedy|Romance           120.0    4.183333
# 318                        Crime|Drama           317.0    4.429022
# 46578           Adventure|Comedy|Drama            77.0    3.883117
# 590            Adventure|Drama|Western           164.0    3.835366
# 7361              Drama|Romance|Sci-Fi           131.0    4.160305
# 4878     Drama|Mystery|Sci-Fi|Thriller           109.0    3.981651
# 5618       Adventure|Animation|Fantasy            87.0    4.155172
# 1213                       Crime|Drama           126.0    4.250000
